# %% [markdown]
# ## Postcode Data Validation

# %%
# Import libraries
import re
import pandas as pd

# %%
# Read in dataset
postcodes = pd.read_csv('datasets/sp_addresses.csv')

# %%
# Check original data shape, types and missing entries
postcodes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57049 entries, 0 to 57048
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       57049 non-null  int64
#  1   tipo_logr        57049 non-null  object
#  2   logr_nome        57049 non-null  object
#  3   logr_compl       57049 non-null  object
#  4   numero           41 non-null     object
#  5   bairro           57049 non-null  object
#  6   nome_localidade  57049 non-null  object
#  7   sigla_uf         57049 non-null  object
#  8   cep              57049 non-null  float64
#  9   latitude         57002 non-null  float64
#  10  longitude        57002 non-null  float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 4.8+ MB

# %%
# Read dataset head
postcodes.head()
# Out:
#    Unnamed: 0 tipo_logr            logr_nome               logr_compl numero  \
# 0      543013       Rua         George Dantu         Rua George Dantu    NaN
# 1      543014       Rua  Maria Augusta Fiske  Rua Maria Augusta Fiske    NaN
# 2      543015       Rua    Doutor Nilo Cairo    Rua Doutor Nilo Cairo    NaN
# 3      543016       Rua    Leonel Martiniano    Rua Leonel Martiniano    NaN
# 4      543017       Rua          André Polak          Rua André Polak    NaN
#
#                    bairro nome_localidade sigla_uf        cep   latitude  \
# 0  Chácara Maria Trindade       São Paulo       SP  5275051.0 -23.422697
# 1  Chácara Maria Trindade       São Paulo       SP  5275055.0 -23.424251
# 2  Chácara Maria Trindade       São Paulo       SP  5275060.0 -23.411648
# 3  Chácara Maria Trindade       São Paulo       SP  5275065.0 -23.422471
# 4  Chácara Maria Trindade       São Paulo       SP  5275070.0 -23.422164
#
#    longitude
# 0 -46.812013
# 1 -46.812687
# 2 -46.815519
# 3 -46.823359
# 4 -46.807962

# %%
# Merge columns 'tipo_logr' and 'logr_name' into a single column
postcodes['rua'] = postcodes['tipo_logr'] + ' ' + postcodes['logr_nome']
postcodes['rua'] = postcodes['rua'].str.title().str.strip()

# %%
# Create function to remove house numbers to prevent home identification and preserve private information
def cleanup_address_number(address):
    return re.sub(r'[0-9]+', '', address).replace(',', '').strip()
     
# Apply string formatting function to the column 'Rua'
postcodes['rua'] = postcodes['rua'].apply(cleanup_address_number)

# Validate transformation
postcodes
# Out:
#        Unnamed: 0 tipo_logr                        logr_nome  \
# 0          543013       Rua                     George Dantu
# 1          543014       Rua              Maria Augusta Fiske
# 2          543015       Rua                Doutor Nilo Cairo
# 3          543016       Rua                Leonel Martiniano
# 4          543017       Rua                      André Polak
# ...           ...       ...                              ...
# 57044     1104300       Rua            Belmiro Valverde, 218
# 57045     1104333  Travessa        Marlucia Augusta fagundes
# 57046     1104335       Rua                      Flor Bonita
# 57047     1104338       Rua  Dona Faustina Leonardo Januário
# 57048     1104360   Avenida           dos Metalúrgicos, 2161
#
#                                 logr_compl numero  \
# 0                         Rua George Dantu    NaN
# 1                  Rua Maria Augusta Fiske    NaN
# 2                    Rua Doutor Nilo Cairo    NaN
# 3                    Rua Leonel Martiniano    NaN
# 4                          Rua André Polak    NaN
# ...                                    ...    ...
# 57044            Rua Belmiro Valverde, 218    NaN
# 57045   Travessa Marlucia Augusta fagundes    NaN
# 57046                      Rua Flor Bonita    NaN
# 57047  Rua Dona Faustina Leonardo Januário    NaN
# 57048       Avenida dos Metalúrgicos, 2161    NaN
#
#                                            bairro nome_localidade sigla_uf  \
# 0                          Chácara Maria Trindade       São Paulo       SP
# 1                          Chácara Maria Trindade       São Paulo       SP
# 2                          Chácara Maria Trindade       São Paulo       SP
# 3                          Chácara Maria Trindade       São Paulo       SP
# 4                          Chácara Maria Trindade       São Paulo       SP
# ...                                           ...             ...      ...
# 57044                                     Lajeado       São Paulo       SP
# 57045                Jardim São Paulo(Zona Leste)       São Paulo       SP
# 57046                              Cidade Popular       São Paulo       SP
# 57047  Conjunto Habitacional Juscelino Kubitschek       São Paulo       SP
# 57048                           Cidade Tiradentes       São Paulo       SP
#
#              cep   latitude  longitude                                  rua
# 0      5275051.0 -23.422697 -46.812013                     Rua George Dantu
# 1      5275055.0 -23.424251 -46.812687              Rua Maria Augusta Fiske
# 2      5275060.0 -23.411648 -46.815519                Rua Doutor Nilo Cairo
# 3      5275065.0 -23.422471 -46.823359                Rua Leonel Martiniano
# 4      5275070.0 -23.422164 -46.807962                      Rua André Polak
# ...          ...        ...        ...                                  ...
# 57044  8450959.0 -23.541529 -46.410636                 Rua Belmiro Valverde
# 57045  8461375.0 -23.560021 -46.405634   Travessa Marlucia Augusta Fagundes
# 57046  8461137.0 -23.559476 -46.588920                      Rua Flor Bonita
# 57047  8465055.0 -23.555771 -46.639557  Rua Dona Faustina Leonardo Januário
# 57048  8471959.0 -23.599381 -46.401247             Avenida Dos Metalúrgicos
#
# [57049 rows x 12 columns]

# %%
# Validate column 'nome_localidade'
postcodes['nome_localidade'].value_counts()
# Out:
# São Paulo    57049
# Name: nome_localidade, dtype: int64

# %%
# Keep relevant columns
postcodes = postcodes[['rua', 'bairro', 'cep', 'latitude', 'longitude']]

# %%
# Rename columns appropriately
postcodes.columns = ['address', 'ward', 'postcode', 'latitude', 'longitude']

# %%
# Save validated dataset to csv
postcodes.to_csv('datasets/sp_postcodes.csv')
